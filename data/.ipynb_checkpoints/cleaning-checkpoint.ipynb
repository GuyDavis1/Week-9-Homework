# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
prop=pd.read_csv("base_data_for_cleaning\postcode_lga.csv")
prop
# Out:
#        idx              State       LGA  Postcode
# 0     3840           Victoria    Alpine      3678
# 1     3841           Victoria    Alpine      3691
# 2     3842           Victoria    Alpine      3695
# 3     3843           Victoria    Alpine      3697
# 4     3844           Victoria    Alpine      3698
# ...    ...                ...       ...       ...
# 1552  5392  Western Australia  Armadale      6121
# 1553  5393  Western Australia  Armadale      6122
# 1554  5394  Western Australia  Armadale      6124
# 1555  5395  Western Australia  Armadale      6155
# 1556  5396  Western Australia  Armadale      6164
#
# [1557 rows x 4 columns]

# %%
prop[prop.Postcode==3129]
# Out:
#        idx     State         LGA  Postcode
# 150   3990  Victoria  Boroondara      3129
# 770   4610  Victoria  Manningham      3129
# 1405  5245  Victoria  Whitehorse      3129

# %%
post=pd.read_csv("base_data_for_cleaning\postcode_suburb.csv")
post
# Out:
#        postcode                          suburb state  \
# 0           200  AUSTRALIAN NATIONAL UNIVERSITY   ACT
# 1           221                          BARTON   ACT
# 2           800                          DARWIN    NT
# 3           801                          DARWIN    NT
# 4           804                           PARAP    NT
# ...         ...                             ...   ...
# 16075      9010                        BRISBANE   QLD
# 16076      9013                        BRISBANE   QLD
# 16077      9015                        BRISBANE   QLD
# 16078      9020                        BRISBANE   QLD
# 16079         0                             NaN   NaN
#
#                                 dc  \
# 0      AUSTRALIAN NATIONAL UNI LPO
# 1                              NaN
# 2           DARWIN DELIVERY CENTRE
# 3           DARWIN DELIVERY CENTRE
# 4                            PARAP
# ...                            ...
# 16075           CITY DC - BRISBANE
# 16076           CITY DC - BRISBANE
# 16077           CITY DC - BRISBANE
# 16078           CITY DC - BRISBANE
# 16079                          NaN
#
#                                                 type        lat         lon
# 0      Post Office Boxes                             -35.277272  149.117136
# 1      LVR                                           -35.201372  149.095065
# 2      Delivery Area                                 -12.801028  130.955789
# 3      Post Office Boxes                             -12.801028  130.955789
# 4      Post Office Boxes                             -12.432181  130.843310
# ...                                              ...        ...         ...
# 16075  LVR                                           -27.603479  152.823141
# 16076  LVR                                           -27.603479  152.823141
# 16077  LVR                                           -27.603479  152.823141
# 16078  LVR                                           -27.603479  152.823141
# 16079                                            NaN        NaN         NaN
#
# [16080 rows x 7 columns]

# %%
post[post.suburb=="BOX HILL NORTH"]
# Out:
#       postcode          suburb state           dc  \
# 5588      3129  BOX HILL NORTH   VIC  BOX HILL DC
#
#                                                type        lat         lon
# 5588  Delivery Area                                 -37.801761  145.126869

# %%
prop=prop.merge(post,left_on="Postcode",right_on="postcode")
prop=prop[(prop.state=="VIC")]
prop
# Out:
#        idx     State           LGA  Postcode  postcode          suburb state  \
# 0     3840  Victoria        Alpine      3678      3678    BOBINAWARRAH   VIC
# 1     3840  Victoria        Alpine      3678      3678       BOORHAMAN   VIC
# 2     3840  Victoria        Alpine      3678      3678  BOORHAMAN EAST   VIC
# 3     3840  Victoria        Alpine      3678      3678          BOWSER   VIC
# 4     3840  Victoria        Alpine      3678      3678        BYAWATHA   VIC
# ...    ...       ...           ...       ...       ...             ...   ...
# 8929  5368  Victoria  Yarriambiack      3396      3396           YARTO   VIC
# 8930  5375  Victoria  Yarriambiack      3485      3485          BANYAN   VIC
# 8931  5375  Victoria  Yarriambiack      3485      3485       WATCHUPGA   VIC
# 8932  5375  Victoria  Yarriambiack      3485      3485       WILLANGIE   VIC
# 8933  5375  Victoria  Yarriambiack      3485      3485       WOOMELANG   VIC
#
#                 dc                                           type        lat  \
# 0           MILAWA  Delivery Area                                 -36.521737
# 1       WANGARATTA  Delivery Area                                 -36.230384
# 2       WANGARATTA  Delivery Area                                 -36.176096
# 3       WANGARATTA  Delivery Area                                 -36.314617
# 4       WANGARATTA  Delivery Area                                 -36.287608
# ...            ...                                            ...        ...
# 8929  HOPETOUN LPO  Delivery Area                                 -35.517724
# 8930     WOOMELANG  Delivery Area                                 -35.635088
# 8931     WOOMELANG  Delivery Area                                 -35.758053
# 8932     WOOMELANG  Delivery Area                                 -35.719379
# 8933     WOOMELANG  Delivery Area                                 -35.680879
#
#              lon
# 0     146.498737
# 1     146.304461
# 2     146.314773
# 3     146.364425
# 4     146.448151
# ...          ...
# 8929  142.358521
# 8930  142.766116
# 8931  142.708455
# 8932  142.796561
# 8933  142.666099
#
# [8533 rows x 11 columns]

# %%
prop[prop.suburb=="BOX HILL NORTH"]
# Out:
#        idx     State         LGA  Postcode  postcode          suburb state  \
# 3126  3990  Victoria  Boroondara      3129      3129  BOX HILL NORTH   VIC
# 3129  4610  Victoria  Manningham      3129      3129  BOX HILL NORTH   VIC
# 3132  5245  Victoria  Whitehorse      3129      3129  BOX HILL NORTH   VIC
#
#                dc                                           type        lat  \
# 3126  BOX HILL DC  Delivery Area                                 -37.801761
# 3129  BOX HILL DC  Delivery Area                                 -37.801761
# 3132  BOX HILL DC  Delivery Area                                 -37.801761
#
#              lon
# 3126  145.126869
# 3129  145.126869
# 3132  145.126869

# %%
#get metro postcodes
prop=prop[prop.Postcode.between(3000,3211)|
    prop.Postcode.between(3335,3336)|
    prop.Postcode.between(3338,3338)|
    prop.Postcode.between(3427,3429)|
    prop.Postcode.between(3750,3752)|
    prop.Postcode.between(3754,3755)|
    prop.Postcode.between(3759,3761)|
    prop.Postcode.between(3765,3775)|
    prop.Postcode.between(3781,3787)|
    prop.Postcode.between(3788,3815)|
    prop.Postcode.between(3910,3920)|
    prop.Postcode.between(3926,3944)|
    prop.Postcode.between(3975,3978)|
    prop.Postcode.between(3980,3980)]

# %%
prop=prop[["LGA","suburb"]].drop_duplicates()
prop.suburb=prop.suburb.str.title()
prop
# Out:
#                LGA            suburb
# 1740       Banyule         Thornbury
# 1741       Darebin         Thornbury
# 1742      Moreland         Thornbury
# 1743       Banyule  Northland Centre
# 1744       Banyule           Preston
# ...            ...               ...
# 8922  Yarra Ranges        Sherbrooke
# 8923  Yarra Ranges         The Patch
# 8924  Yarra Ranges           Monbulk
# 8925  Yarra Ranges            Silvan
# 8926  Yarra Ranges      Mount Evelyn
#
# [1546 rows x 2 columns]

# %%
prop=prop.append({"LGA":"Boroondara","suburb":"Deepdene"}, ignore_index=True)
prop=prop.append({"LGA":"Nillumbik","suburb":"Bend of Islands"}, ignore_index=True)
prop=prop.append({"LGA":"Banyule","suburb":"St Helena"}, ignore_index=True)
prop=prop.append({"LGA":"Casey","suburb":"Botanic Ridge"}, ignore_index=True)
prop=prop.append({"LGA":"Moonee Valley","suburb":"Essendon Fields"}, ignore_index=True)
prop=prop.append({"LGA":"Brimbank","suburb":"Sunshine"}, ignore_index=True)
prop=prop.append({"LGA":"Wyndham","suburb":"Williams Landing"}, ignore_index=True)
prop=prop.append({"LGA":"Wyndham","suburb":"Manor Lakes"}, ignore_index=True)
prop=prop.append({"LGA":"Bayside","suburb":"Hampton"}, ignore_index=True)

# %%
prop[prop.LGA=="Bayside"]
# Out:
#          LGA             suburb
# 199  Bayside          Caulfield
# 200  Bayside    Caulfield South
# 201  Bayside   Hopetoun Gardens
# 205  Bayside      Brighton Road
# 206  Bayside             Elwood
# 211  Bayside        Elsternwick
# 212  Bayside         Gardenvale
# 213  Bayside          Ripponlea
# 220  Bayside           Brighton
# 221  Bayside     Brighton North
# 222  Bayside              Dendy
# 229  Bayside      Brighton East
# 230  Bayside         North Road
# 233  Bayside       Hampton East
# 234  Bayside      Hampton North
# 237  Bayside          Moorabbin
# 238  Bayside            Wishart
# 243  Bayside            Highett
# 245  Bayside        Sandringham
# 246  Bayside         Cheltenham
# 247  Bayside    Cheltenham East
# 248  Bayside   Cheltenham North
# 249  Bayside   Southland Centre
# 254  Bayside          Beaumaris
# 255  Bayside         Black Rock
# 256  Bayside   Black Rock North
# 257  Bayside             Cromer
# 262  Bayside            Mentone
# 263  Bayside       Mentone East
# 264  Bayside  Moorabbin Airport
# 268  Bayside          Bentleigh
# 269  Bayside           Mckinnon
# 270  Bayside             Ormond
# 271  Bayside          Patterson

# %%
prop[prop.suburb.str.contains("Box")]
# Out:
#              LGA            suburb
# 366   Boroondara    Box Hill North
# 369   Manningham    Box Hill North
# 372   Whitehorse    Box Hill North
# 1531  Whitehorse          Box Hill
# 1532  Whitehorse  Box Hill Central
# 1533  Whitehorse    Box Hill South

# %%
suburb_rents=pd.read_csv("base_data_for_cleaning\suburb_rents.csv")
suburb_rents["Suburb"]=pd.DataFrame(suburb_rents.Suburb.str.split("-"))
suburb_rents=suburb_rents.explode(column="Suburb")
suburb_rents
# Out:
#             Suburb  Median
# 0      Albert Park   500.0
# 0      Middle Park   500.0
# 0    West St Kilda   500.0
# 1         Armadale   440.0
# 2    Carlton North   580.0
# ..             ...     ...
# 144      Traralgon   345.0
# 145    Wanagaratta   330.0
# 146       Warragul   380.0
# 147    Warrnambool   360.0
# 148        Wodonga   350.0
#
# [218 rows x 2 columns]

# %%
suburb_rents[suburb_rents.Suburb.str.contains("Box")]
# Out:
#       Suburb  Median
# 24  Box Hill   400.0

# %%
prop.drop_duplicates()
# Out:
#                 LGA            suburb
# 0           Banyule         Thornbury
# 1           Darebin         Thornbury
# 2          Moreland         Thornbury
# 3           Banyule  Northland Centre
# 4           Banyule           Preston
# ...             ...               ...
# 1549          Casey     Botanic Ridge
# 1550  Moonee Valley   Essendon Fields
# 1551       Brimbank          Sunshine
# 1552        Wyndham  Williams Landing
# 1553        Wyndham       Manor Lakes
#
# [1554 rows x 2 columns]

# %%
merged=suburb_rents.merge(prop,left_on="Suburb",right_on="suburb",how="outer")

merged
# Out:
#              Suburb  Median            LGA            suburb
# 0       Albert Park   500.0      Melbourne       Albert Park
# 1       Albert Park   500.0   Port Phillip       Albert Park
# 2       Middle Park   500.0      Melbourne       Middle Park
# 3       Middle Park   500.0   Port Phillip       Middle Park
# 4     West St Kilda   500.0            NaN               NaN
# ...             ...     ...            ...               ...
# 1612            NaN     NaN        Banyule         St Helena
# 1613            NaN     NaN          Casey     Botanic Ridge
# 1614            NaN     NaN  Moonee Valley   Essendon Fields
# 1615            NaN     NaN        Wyndham  Williams Landing
# 1616            NaN     NaN        Wyndham       Manor Lakes
#
# [1617 rows x 4 columns]

# %%
merged[merged.suburb=="Box Hill North"]
# Out:
#     Suburb  Median         LGA          suburb
# 744    NaN     NaN  Boroondara  Box Hill North
# 745    NaN     NaN  Manningham  Box Hill North
# 746    NaN     NaN  Whitehorse  Box Hill North

# %%
merged.isnull().sum()
# Out:
# Suburb    1134
# Median    1134
# LGA         63
# suburb      63
# dtype: int64

# %%
lga_meds=merged.groupby("LGA").Median.mean().reset_index()
lga_meds.columns=["LGA","lga_med"]
lga_meds
# Out:
#                      LGA     lga_med
# 0                Banyule  432.250000
# 1                Baw Baw         NaN
# 2                Bayside  511.333333
# 3             Boroondara  458.000000
# 4               Brimbank  382.083333
# 5               Cardinia  390.000000
# 6                  Casey  392.777778
# 7                Darebin  431.625000
# 8              Frankston  388.571429
# 9              Glen Eira  464.769231
# 10     Greater Dandenong  409.062500
# 11       Greater Geelong  360.000000
# 12           Hobsons Bay  463.125000
# 13                  Hume  384.000000
# 14              Kingston  430.333333
# 15                  Knox  420.384615
# 16        Macedon Ranges  378.666667
# 17            Manningham  450.687500
# 18             Mansfield         NaN
# 19           Maribyrnong  422.307692
# 20             Maroondah  428.750000
# 21             Melbourne  447.333333
# 22                Melton  366.666667
# 23              Mitchell  378.000000
# 24                Monash  426.590909
# 25         Moonee Valley  400.000000
# 26             Moorabool         NaN
# 27              Moreland  421.347826
# 28  Mornington Peninsula  440.166667
# 29           Murrindindi  410.000000
# 30             Nillumbik  433.750000
# 31          Port Phillip  462.076923
# 32           Stonnington  427.222222
# 33            Whitehorse  457.750000
# 34            Whittlesea  384.600000
# 35               Wyndham  378.750000
# 36                 Yarra  458.550000
# 37          Yarra Ranges  411.666667

# %%
merged=merged.merge(lga_meds,how="left",on="LGA")
merged
# Out:
#              Suburb  Median            LGA            suburb     lga_med
# 0       Albert Park   500.0      Melbourne       Albert Park  447.333333
# 1       Albert Park   500.0   Port Phillip       Albert Park  462.076923
# 2       Middle Park   500.0      Melbourne       Middle Park  447.333333
# 3       Middle Park   500.0   Port Phillip       Middle Park  462.076923
# 4     West St Kilda   500.0            NaN               NaN         NaN
# ...             ...     ...            ...               ...         ...
# 1612            NaN     NaN        Banyule         St Helena  432.250000
# 1613            NaN     NaN          Casey     Botanic Ridge  392.777778
# 1614            NaN     NaN  Moonee Valley   Essendon Fields  400.000000
# 1615            NaN     NaN        Wyndham  Williams Landing  378.750000
# 1616            NaN     NaN        Wyndham       Manor Lakes  378.750000
#
# [1617 rows x 5 columns]

# %%
merged.iloc[merged.Median.isnull(),1]=merged[merged.Median.isnull()].lga_med
merged[merged.suburb=="Box Hill North"]
# Out:
#     Suburb    Median         LGA          suburb   lga_med
# 744    NaN  458.0000  Boroondara  Box Hill North  458.0000
# 745    NaN  450.6875  Manningham  Box Hill North  450.6875
# 746    NaN  457.7500  Whitehorse  Box Hill North  457.7500

# %%
merged=merged[["suburb","Median"]][~merged.suburb.isnull()].drop_duplicates()
merged
# Out:
#                 suburb      Median
# 0          Albert Park  500.000000
# 2          Middle Park  500.000000
# 5             Armadale  440.000000
# 8        Carlton North  580.000000
# 11             Carlton  340.000000
# ...                ...         ...
# 1612         St Helena  432.250000
# 1613     Botanic Ridge  392.777778
# 1614   Essendon Fields  400.000000
# 1615  Williams Landing  378.750000
# 1616       Manor Lakes  378.750000
#
# [1282 rows x 2 columns]

# %%
merged[merged.suburb.str.contains("Box")]
# Out:
#                 suburb    Median
# 83            Box Hill  400.0000
# 744     Box Hill North  458.0000
# 745     Box Hill North  450.6875
# 746     Box Hill North  457.7500
# 1598  Box Hill Central  457.7500
# 1599    Box Hill South  457.7500

# %%
merged[["suburb","Median"]][~merged.Median.isnull()].to_csv("suburb_rents.csv")

# %%
merged=merged[["suburb","Median"]][~merged.Median.isnull()].groupby("suburb").Median.median().reset_index()

# %%
merged.loc[merged.suburb=="Mckinnon","suburb"]="McKinnon"
merged.loc[merged.suburb=="Mcmahons Creek","suburb"]="McMahons Creek"

# %%
merged.loc[merged.suburb.str.contains("Dee"),"suburb"]
# Out:
# 174           Deepdene
# 175          Deer Park
# 176     Deer Park East
# 177    Deer Park North
# Name: suburb, dtype: object

# %%
merged.to_csv("suburb_rents.csv")
